# %% [markdown]
# # นายวรธน สาดแสงจันทร์ 6110401641

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## 1

# %%
medals = pd.read_csv('olympics.csv')

# %% [markdown]
# ## 2

# %%
medals
# Out:
#                                        Unnamed: 0  № Summer  01 !  02 !  03 !  \
# 0                               Afghanistan (AFG)        13     0     0     2
# 1                                   Algeria (ALG)        12     5     2     8
# 2                                 Argentina (ARG)        23    18    24    28
# 3                                   Armenia (ARM)         5     1     2     9
# 4                         Australasia (ANZ) [ANZ]         2     3     4     5
# 5                       Australia (AUS) [AUS] [Z]        25   139   152   177
# 6                                   Austria (AUT)        26    18    33    35
# 7                                Azerbaijan (AZE)         5     6     5    15
# 8                                   Bahamas (BAH)        15     5     2     5
# 9                                   Bahrain (BRN)         8     0     0     1
# 10                           Barbados (BAR) [BAR]        11     0     0     1
# ...

# %%
medals.columns
# Out:
# Index(['Unnamed: 0', '№ Summer', '01 !', '02 !', '03 !', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1'],
#       dtype='object')

# %% [markdown]
# ## 3

# %%
medals.columns = ['Country','SummerGame','SummerGold','SummerSilver','SummerBronze','WinterGame','WinterGold','WinterSilver','WinterBronze']

# %%
medals
# Out:
#                                           Country  SummerGame  SummerGold  \
# 0                               Afghanistan (AFG)          13           0
# 1                                   Algeria (ALG)          12           5
# 2                                 Argentina (ARG)          23          18
# 3                                   Armenia (ARM)           5           1
# 4                         Australasia (ANZ) [ANZ]           2           3
# 5                       Australia (AUS) [AUS] [Z]          25         139
# 6                                   Austria (AUT)          26          18
# 7                                Azerbaijan (AZE)           5           6
# 8                                   Bahamas (BAH)          15           5
# 9                                   Bahrain (BRN)           8           0
# 10                           Barbados (BAR) [BAR]          11           0
# 11                                  Belarus (BLR)           5          12
# ...

# %% [markdown]
# ## 4

# %%
CountryCode = medals['Country']

# %%
CountryCode = CountryCode.str.extract("\((.*)\)")

# %%
medals['CountryCode'] = CountryCode

# %%
medals = medals[['CountryCode','Country','SummerGame','SummerGold','SummerSilver','SummerBronze','WinterGame','WinterGold','WinterSilver','WinterBronze']]

# %%
medals
# Out:
#     CountryCode                                       Country  SummerGame  \
# 0           AFG                             Afghanistan (AFG)          13
# 1           ALG                                 Algeria (ALG)          12
# 2           ARG                               Argentina (ARG)          23
# 3           ARM                                 Armenia (ARM)           5
# 4           ANZ                       Australasia (ANZ) [ANZ]           2
# 5           AUS                     Australia (AUS) [AUS] [Z]          25
# 6           AUT                                 Austria (AUT)          26
# 7           AZE                              Azerbaijan (AZE)           5
# 8           BAH                                 Bahamas (BAH)          15
# 9           BRN                                 Bahrain (BRN)           8
# 10          BAR                          Barbados (BAR) [BAR]          11
# 11          BLR                                 Belarus (BLR)           5
# ...

# %% [markdown]
# ## 5

# %%
medals['CountryCode'].is_unique
# Out:
# True

# %% [markdown]
# ## 6

# %%
medals = medals.set_index('CountryCode')

# %% [markdown]
# ## 7

# %%
medals.loc[: , 'SummerGold']
# Out:
# CountryCode
# AFG      0
# ALG      5
# ARG     18
# ARM      1
# ANZ      3
# AUS    139
# AUT     18
# AZE      6
# BAH      5
# BRN      0
# BAR      0
# BLR     12
# BEL     37
# BER      0
# BOH      0
# BOT      0
# BRA     23
# BWI      0
# BUL     51
# BDI      1
# CMR      3
# CAN     59
# CHI      2
# CHN    201
# COL      2
# CRC      1
# CIV      0
# CRO      6
# CUB     72
# CYP      0
#       ...
# ESP     37
# SRI      0
# SUD      0
# SUR      1
# SWE    143
# SUI     47
# SYR      1
# TPE      2
# TJK      0
# TAN      0
# THA      7
# TOG      0
# TGA      0
# TRI      2
# TUN      3
# TUR     39
# UGA      2
# UKR     33
# UAE      1
# USA    976
# URU      2
# UZB      5
# VEN      2
# VIE      0
# ISV      0
# YUG     26
# IOP      0
# ZAM      0
# ZIM      3
# ZZX      8
# Name: SummerGold, Length: 146, dtype: int64

# %% [markdown]
# ## 8

# %%
medals.loc['USA']
# Out:
# Country         United States (USA) [P] [Q] [R] [Z]
# SummerGame                                       26
# SummerGold                                      976
# SummerSilver                                    757
# SummerBronze                                    666
# WinterGame                                       22
# WinterGold                                       96
# WinterSilver                                    102
# WinterBronze                                     84
# Name: USA, dtype: object

# %% [markdown]
# ## 9

# %%
medals.iloc[:,0:5]
# Out:
#                                                   Country  SummerGame  \
# CountryCode
# AFG                                     Afghanistan (AFG)          13
# ALG                                         Algeria (ALG)          12
# ARG                                       Argentina (ARG)          23
# ARM                                         Armenia (ARM)           5
# ANZ                               Australasia (ANZ) [ANZ]           2
# AUS                             Australia (AUS) [AUS] [Z]          25
# AUT                                         Austria (AUT)          26
# AZE                                      Azerbaijan (AZE)           5
# BAH                                         Bahamas (BAH)          15
# BRN                                         Bahrain (BRN)           8
# BAR                                  Barbados (BAR) [BAR]          11
# BLR                                         Belarus (BLR)           5
# ...

# %% [markdown]
# ## 10

# %%
medals.loc[['THA','SIN','MAS'],['Country','SummerGold','WinterGold']]
# Out:
#                           Country  SummerGold  WinterGold
# CountryCode
# THA                Thailand (THA)           7           0
# SIN               Singapore (SIN)           0           0
# MAS          Malaysia (MAS) [MAS]           0           0

# %% [markdown]
# ## 11

# %%
medals.loc[['FRA','ESP'],['Country','SummerSilver','SummerBronze']]
# Out:
#                               Country  SummerSilver  SummerBronze
# CountryCode
# FRA          France (FRA) [O] [P] [Z]           223           246
# ESP                   Spain (ESP) [Z]            59            35

# %% [markdown]
# ## 12

# %%
medals.loc[(medals['SummerGame'] >= 24)]
# Out:
#                                          Country  SummerGame  SummerGold  \
# CountryCode
# AUS                    Australia (AUS) [AUS] [Z]          25         139
# AUT                                Austria (AUT)          26          18
# BEL                                Belgium (BEL)          25          37
# CAN                                 Canada (CAN)          25          59
# DEN                            Denmark (DEN) [Z]          26          43
# FIN                                Finland (FIN)          24         101
# FRA                     France (FRA) [O] [P] [Z]          27         202
# GBR                Great Britain (GBR) [GBR] [Z]          27         236
# GRE                             Greece (GRE) [Z]          27          30
# HUN                                Hungary (HUN)          25         167
# ITA                          Italy (ITA) [M] [S]          26         198
# NED                        Netherlands (NED) [Z]          25          77
# ...

# %% [markdown]
# ## 13

# %%
medals.loc[(medals['SummerGold'])>= 200]
# Out:
#                                          Country  SummerGame  SummerGold  \
# CountryCode
# CHN                            China (CHN) [CHN]           9         201
# FRA                     France (FRA) [O] [P] [Z]          27         202
# GBR                Great Britain (GBR) [GBR] [Z]          27         236
# URS                     Soviet Union (URS) [URS]           9         395
# USA          United States (USA) [P] [Q] [R] [Z]          26         976
#
#              SummerSilver  SummerBronze  WinterGame  WinterGold  WinterSilver  \
# CountryCode
# CHN                   146           126          10          12            22
# FRA                   223           246          22          31            31
# GBR                   272           272          22          10             4
# URS                   319           296           9          78            57
# USA                   757           666          22          96           102
#
#              WinterBronze
# ...

# %% [markdown]
# ## 14

# %%
medals.loc[(medals['SummerGold'] >= 200) & (medals['SummerSilver'] >= 200) ]
# Out:
#                                          Country  SummerGame  SummerGold  \
# CountryCode
# FRA                     France (FRA) [O] [P] [Z]          27         202
# GBR                Great Britain (GBR) [GBR] [Z]          27         236
# URS                     Soviet Union (URS) [URS]           9         395
# USA          United States (USA) [P] [Q] [R] [Z]          26         976
#
#              SummerSilver  SummerBronze  WinterGame  WinterGold  WinterSilver  \
# CountryCode
# FRA                   223           246          22          31            31
# GBR                   272           272          22          10             4
# URS                   319           296           9          78            57
# USA                   757           666          22          96           102
#
#              WinterBronze
# CountryCode
# FRA                    47
# GBR                    12
# URS                    59
# USA                    84

# %% [markdown]
# ## 15

# %%
medals.loc[(medals['WinterGold'] > medals['WinterSilver'])]
# Out:
#                                         Country  SummerGame  SummerGold  \
# CountryCode
# AUS                   Australia (AUS) [AUS] [Z]          25         139
# BLR                               Belarus (BLR)           5          12
# CAN                                Canada (CAN)          25          59
# EST                               Estonia (EST)          11           9
# EUA          United Team of Germany (EUA) [EUA]           3          28
# GDR                    East Germany (GDR) [GDR]           5         153
# GBR               Great Britain (GBR) [GBR] [Z]          27         236
# ITA                         Italy (ITA) [M] [S]          26         198
# KOR                           South Korea (KOR)          16          81
# NOR                            Norway (NOR) [Q]          24          56
# RUS                          Russia (RUS) [RUS]           5         132
# URS                    Soviet Union (URS) [URS]           9         395
# ...

# %% [markdown]
# ## 16

# %%
medals.loc[(medals['WinterGold'] > medals['WinterSilver'] + medals['WinterBronze'])]
# Out:
#                       Country  SummerGame  SummerGold  SummerSilver  \
# CountryCode
# EST             Estonia (EST)          11           9             9
# UZB          Uzbekistan (UZB)           5           5             5
#
#              SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze
# CountryCode
# EST                    15           9           4             2             1
# UZB                    10           6           1             0             0

# %% [markdown]
# ## 17

# %%
startWithA = medals['Country']

# %%
startWithA.str.startswith('A')
# Out:
# CountryCode
# AFG     True
# ALG     True
# ARG     True
# ARM     True
# ANZ     True
# AUS     True
# AUT     True
# AZE     True
# BAH    False
# BRN    False
# BAR    False
# BLR    False
# BEL    False
# BER    False
# BOH    False
# BOT    False
# BRA    False
# BWI    False
# BUL    False
# BDI    False
# CMR    False
# CAN    False
# CHI    False
# CHN    False
# COL    False
# CRC    False
# CIV    False
# CRO    False
# CUB    False
# CYP    False
#        ...
# ESP    False
# SRI    False
# SUD    False
# SUR    False
# SWE    False
# SUI    False
# SYR    False
# TPE    False
# TJK    False
# TAN    False
# THA    False
# TOG    False
# TGA    False
# TRI    False
# TUN    False
# TUR    False
# UGA    False
# UKR    False
# UAE    False
# USA    False
# URU    False
# UZB    False
# VEN    False
# VIE    False
# ISV    False
# YUG    False
# IOP    False
# ZAM    False
# ZIM    False
# ZZX    False
# Name: Country, Length: 146, dtype: bool

# %%
medals[startWithA.str.startswith('A')].loc[:, 'SummerGold':'SummerBronze']
# Out:
#              SummerGold  SummerSilver  SummerBronze
# CountryCode
# AFG                   0             0             2
# ALG                   5             2             8
# ARG                  18            24            28
# ARM                   1             2             9
# ANZ                   3             4             5
# AUS                 139           152           177
# AUT                  18            33            35
# AZE                   6             5            15

# %% [markdown]
# ## 18

# %%
medals.loc[medals['SummerGame'] == medals['SummerGame'].max()]
# Out:
#                                    Country  SummerGame  SummerGold  \
# CountryCode
# FRA               France (FRA) [O] [P] [Z]          27         202
# GBR          Great Britain (GBR) [GBR] [Z]          27         236
# GRE                       Greece (GRE) [Z]          27          30
# SUI                      Switzerland (SUI)          27          47
#
#              SummerSilver  SummerBronze  WinterGame  WinterGold  WinterSilver  \
# CountryCode
# FRA                   223           246          22          31            31
# GBR                   272           272          22          10             4
# GRE                    42            39          18           0             0
# SUI                    73            65          22          50            40
#
#              WinterBronze
# CountryCode
# FRA                    47
# GBR                    12
# GRE                     0
# SUI                    48

# %%
medals['SummerGame'].max()
# Out:
# 27

# %% [markdown]
# ## 19

# %%
medals.loc[medals['SummerGame'] == medals['SummerGame'].max()].loc[:,'Country':'SummerGame']
# Out:
#                                    Country  SummerGame
# CountryCode
# FRA               France (FRA) [O] [P] [Z]          27
# GBR          Great Britain (GBR) [GBR] [Z]          27
# GRE                       Greece (GRE) [Z]          27
# SUI                      Switzerland (SUI)          27

# %% [markdown]
# ## 20

# %%
medals.loc[medals['WinterGame'] == medals['WinterGame'].max()]
# Out:
#                                          Country  SummerGame  SummerGold  \
# CountryCode
# AUT                                Austria (AUT)          26          18
# CAN                                 Canada (CAN)          25          59
# FIN                                Finland (FIN)          24         101
# FRA                     France (FRA) [O] [P] [Z]          27         202
# GBR                Great Britain (GBR) [GBR] [Z]          27         236
# HUN                                Hungary (HUN)          25         167
# ITA                          Italy (ITA) [M] [S]          26         198
# NOR                             Norway (NOR) [Q]          24          56
# POL                                 Poland (POL)          20          64
# SWE                             Sweden (SWE) [Z]          26         143
# SUI                            Switzerland (SUI)          27          47
# USA          United States (USA) [P] [Q] [R] [Z]          26         976
#
# ...

# %% [markdown]
# ## 21

# %%
medals['TotalWinter'] = medals['WinterGold'] + medals['WinterSilver'] + medals['WinterBronze']

# %%
medals.loc['Total'] = pd.Series(medals['TotalWinter'].sum(), index = ['TotalWinter'])

# %%
medals
# Out:
#                                                   Country  SummerGame  \
# CountryCode
# AFG                                     Afghanistan (AFG)        13.0
# ALG                                         Algeria (ALG)        12.0
# ARG                                       Argentina (ARG)        23.0
# ARM                                         Armenia (ARM)         5.0
# ANZ                               Australasia (ANZ) [ANZ]         2.0
# AUS                             Australia (AUS) [AUS] [Z]        25.0
# AUT                                         Austria (AUT)        26.0
# AZE                                      Azerbaijan (AZE)         5.0
# BAH                                         Bahamas (BAH)        15.0
# BRN                                         Bahrain (BRN)         8.0
# BAR                                  Barbados (BAR) [BAR]        11.0
# BLR                                         Belarus (BLR)         5.0
# ...

# %%
medals.fillna(0)
# Out:
#                                                   Country  SummerGame  \
# CountryCode
# AFG                                     Afghanistan (AFG)        13.0
# ALG                                         Algeria (ALG)        12.0
# ARG                                       Argentina (ARG)        23.0
# ARM                                         Armenia (ARM)         5.0
# ANZ                               Australasia (ANZ) [ANZ]         2.0
# AUS                             Australia (AUS) [AUS] [Z]        25.0
# AUT                                         Austria (AUT)        26.0
# AZE                                      Azerbaijan (AZE)         5.0
# BAH                                         Bahamas (BAH)        15.0
# BRN                                         Bahrain (BRN)         8.0
# BAR                                  Barbados (BAR) [BAR]        11.0
# BLR                                         Belarus (BLR)         5.0
# ...

# %% [markdown]
# ## 22

# %%
MedalsGoldMean = medals

# %%
MedalsGoldMean = MedalsGoldMean.drop(columns = ['SummerGame','SummerSilver','SummerBronze','WinterGame','WinterSilver','WinterBronze','TotalWinter'])

# %%
MedalsGoldMean.mean()
# Out:
# SummerGold    32.938356
# WinterGold     6.568493
# dtype: float64

# %% [markdown]
# ## 23

# %%
TotalCountryMedalList = list(medals)

# %%
TotalCountryMedalList.remove('SummerGame')

# %%
TotalCountryMedalList.remove('WinterGame')

# %%
TotalCountryMedalList.remove('TotalWinter')

# %%
TotalCountryMedalList
# Out:
# ['Country',
#  'SummerGold',
#  'SummerSilver',
#  'SummerBronze',
#  'WinterGold',
#  'WinterSilver',
#  'WinterBronze']

# %%
medals
# Out:
#                                                   Country  SummerGame  \
# CountryCode
# AFG                                     Afghanistan (AFG)        13.0
# ALG                                         Algeria (ALG)        12.0
# ARG                                       Argentina (ARG)        23.0
# ARM                                         Armenia (ARM)         5.0
# ANZ                               Australasia (ANZ) [ANZ]         2.0
# AUS                             Australia (AUS) [AUS] [Z]        25.0
# AUT                                         Austria (AUT)        26.0
# AZE                                      Azerbaijan (AZE)         5.0
# BAH                                         Bahamas (BAH)        15.0
# BRN                                         Bahrain (BRN)         8.0
# BAR                                  Barbados (BAR) [BAR]        11.0
# BLR                                         Belarus (BLR)         5.0
# ...

# %%
medals['TotalMedals'] = medals[TotalCountryMedalList].sum(axis=1)

# %%
medals.loc['Total'] = pd.Series(medals['TotalMedals'].sum(), index = ['TotalMedals'])

# %%
medals.at['Total','TotalWinter'] = medals['TotalWinter'].sum()

# %%
medals
# Out:
#                                                   Country  SummerGame  \
# CountryCode
# AFG                                     Afghanistan (AFG)        13.0
# ALG                                         Algeria (ALG)        12.0
# ARG                                       Argentina (ARG)        23.0
# ARM                                         Armenia (ARM)         5.0
# ANZ                               Australasia (ANZ) [ANZ]         2.0
# AUS                             Australia (AUS) [AUS] [Z]        25.0
# AUT                                         Austria (AUT)        26.0
# AZE                                      Azerbaijan (AZE)         5.0
# BAH                                         Bahamas (BAH)        15.0
# BRN                                         Bahrain (BRN)         8.0
# BAR                                  Barbados (BAR) [BAR]        11.0
# BLR                                         Belarus (BLR)         5.0
# ...

# %% [markdown]
# ## 24

# %%
MedalsWinterMoreThanSummer = medals

# %%
temp = MedalsWinterMoreThanSummer.loc[(MedalsWinterMoreThanSummer['SummerGold'] 
                                       + MedalsWinterMoreThanSummer['SummerSilver'] 
                                       + MedalsWinterMoreThanSummer['SummerBronze'] 
                                       < MedalsWinterMoreThanSummer['WinterGold'] 
                                       + MedalsWinterMoreThanSummer['WinterSilver'] 
                                       + MedalsWinterMoreThanSummer['WinterGold'] )]

# %%
temp
# Out:
#                          Country  SummerGame  SummerGold  SummerSilver  \
# CountryCode
# AUT                Austria (AUT)        26.0        18.0          33.0
# LIE          Liechtenstein (LIE)        16.0         0.0           0.0
# NOR             Norway (NOR) [Q]        24.0        56.0          49.0
#
#              SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# CountryCode
# AUT                  35.0        22.0        59.0          78.0          81.0
# LIE                   0.0        18.0         2.0           2.0           5.0
# NOR                  43.0        22.0       118.0         111.0         100.0
#
#              TotalWinter  TotalMedals
# CountryCode
# AUT                218.0        304.0
# LIE                  9.0          9.0
# NOR                329.0        477.0

# %%
temp['TotalSummer'] = temp['SummerGold'] + temp['SummerSilver'] + temp['SummerBronze']
# Out:
# C:\Users\PC306\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
temp['TotalWinter'] = temp['WinterGold'] + temp['WinterSilver'] + temp['WinterBronze']
# Out:
# C:\Users\PC306\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
temp = temp.drop(columns = ['SummerGame','SummerGold','SummerSilver','SummerBronze','WinterGame','WinterGold','WinterSilver','WinterBronze','TotalMedals'])

# %%
templist = list(temp)

# %%
templist[1], templist[2] = templist[2], templist[1]

# %%
temp.columns = templist

# %%
temp
# Out:
#                          Country  TotalSummer  TotalWinter
# CountryCode
# AUT                Austria (AUT)        218.0         86.0
# LIE          Liechtenstein (LIE)          9.0          0.0
# NOR             Norway (NOR) [Q]        329.0        148.0

# %% [markdown]
# ## 25

# %%
medals['TotalSummer'] = medals['SummerGold'] + medals['SummerSilver'] + medals['SummerBronze']

# %%
medals.loc[(medals['TotalWinter'] > 0) & (medals['TotalSummer'] <= 0) | (medals['TotalWinter'] == 0) & (medals['TotalSummer'] > 0)]
# Out:
#                                                   Country  SummerGame  \
# CountryCode
# AFG                                     Afghanistan (AFG)        13.0
# ALG                                         Algeria (ALG)        12.0
# ARG                                       Argentina (ARG)        23.0
# ARM                                         Armenia (ARM)         5.0
# ANZ                               Australasia (ANZ) [ANZ]         2.0
# AZE                                      Azerbaijan (AZE)         5.0
# BAH                                         Bahamas (BAH)        15.0
# BRN                                         Bahrain (BRN)         8.0
# BAR                                  Barbados (BAR) [BAR]        11.0
# BER                                         Bermuda (BER)        17.0
# BOH                               Bohemia (BOH) [BOH] [Z]         3.0
# BOT                                        Botswana (BOT)         9.0
# ...

# %% [markdown]
# ## 26

# %%
medals.sort_values(by='SummerGold')
# Out:
#                                                   Country  SummerGame  \
# CountryCode
# AFG                                     Afghanistan (AFG)        13.0
# NAM                                         Namibia (NAM)         6.0
# MNE                                      Montenegro (MNE)         2.0
# MDA                                         Moldova (MDA)         5.0
# MRI                                       Mauritius (MRI)         8.0
# MAS                                  Malaysia (MAS) [MAS]        12.0
# MKD                                       Macedonia (MKD)         5.0
# LIE                                   Liechtenstein (LIE)        16.0
# LIB                                         Lebanon (LIB)        16.0
# KUW                                          Kuwait (KUW)        12.0
# IRQ                                            Iraq (IRQ)        13.0
# ISL                                         Iceland (ISL)        19.0
# ...

# %% [markdown]
# ## 27

# %%
medals.sort_values(by=['SummerGold','SummerGame'], ascending=False)
# Out:
#                                                   Country  SummerGame  \
# CountryCode
# USA                   United States (USA) [P] [Q] [R] [Z]        26.0
# URS                              Soviet Union (URS) [URS]         9.0
# GBR                         Great Britain (GBR) [GBR] [Z]        27.0
# FRA                              France (FRA) [O] [P] [Z]        27.0
# CHN                                     China (CHN) [CHN]         9.0
# ITA                                   Italy (ITA) [M] [S]        26.0
# GER                               Germany (GER) [GER] [Z]        15.0
# HUN                                         Hungary (HUN)        25.0
# GDR                              East Germany (GDR) [GDR]         5.0
# SWE                                      Sweden (SWE) [Z]        26.0
# AUS                             Australia (AUS) [AUS] [Z]        25.0
# RUS                                    Russia (RUS) [RUS]         5.0
# ...

# %% [markdown]
# ## 28
